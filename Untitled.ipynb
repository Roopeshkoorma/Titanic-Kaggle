# %%
import pandas as pd
import numpy as np

df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.drop(["Name","Ticket","Fare","PassengerId"],axis=1,inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0           0       3    male  22.0      1      0   NaN        S
# 1           1       1  female  38.0      1      0   C85        C
# 2           1       3  female  26.0      0      0   NaN        S
# 3           1       1  female  35.0      1      0  C123        S
# 4           0       3    male  35.0      0      0   NaN        S
# ..        ...     ...     ...   ...    ...    ...   ...      ...
# 886         0       2    male  27.0      0      0   NaN        S
# 887         1       1  female  19.0      0      0   B42        S
# 888         0       3  female   NaN      1      2   NaN        S
# 889         1       1    male  26.0      0      0  C148        C
# 890         0       3    male  32.0      0      0   NaN        Q
#
# [891 rows x 8 columns]

# %%
df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Cabin        True
# Embarked     True
# dtype: bool

# %%
df["Age"].fillna(round(df["Age"].mean()),inplace=True)

# %%
df["Cabin"].fillna("G6",inplace=True)

# %%
df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Sex         False
# Age         False
# SibSp       False
# Parch       False
# Cabin       False
# Embarked     True
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder

df["Sex"] = LabelEncoder().fit_transform(df["Sex"])

# %%
df["Embarked"].fillna('S',inplace=True)

# %%
df["Embarked"] = LabelEncoder().fit_transform(df["Embarked"])
df["Cabin"] = LabelEncoder().fit_transform(df["Cabin"])

# %%
df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Sex         False
# Age         False
# SibSp       False
# Parch       False
# Cabin       False
# Embarked    False
# dtype: bool

# %%
x = df.drop(["Survived"],axis=1)
y = df["Survived"]

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch  Cabin  Embarked
# 0         3    1  22.0      1      0    145         2
# 1         1    0  38.0      1      0     81         0
# 2         3    0  26.0      0      0    145         2
# 3         1    0  35.0      1      0     55         2
# 4         3    1  35.0      0      0    145         2
# ..      ...  ...   ...    ...    ...    ...       ...
# 886       2    1  27.0      0      0    145         2
# 887       1    0  19.0      0      0     30         2
# 888       3    0  30.0      1      2    145         2
# 889       1    1  26.0      0      0     60         0
# 890       3    1  32.0      0      0    145         1
#
# [891 rows x 7 columns]

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(df)

# %%
df=pd.DataFrame(data=scaled_data, columns= df.columns)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit_transform(df)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %%
pca = PCA(n_components=5)
new_data = pca.fit_transform(df)
# This will be the new data fed to the algorithm.
principal_Df = pd.DataFrame(data = new_data
             , columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4','principal component 5'])

# %%
x_scale = principal_Df

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20, random_state= 43)

# %%
rand_clf = RandomForestClassifier(random_state=6)

# %%
rand_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=6, verbose=0,
#                        warm_start=False)

# %%
grid_param = {
    "n_estimators" : [90,100,115,130],
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,20,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features' : ['auto','log2']
}

# %%
grid_search = GridSearchCV(estimator=rand_clf,param_grid=grid_param,cv=5,n_jobs =-1,verbose = 3)

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20736 candidates, totalling 103680 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 5400 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 6264 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 19.9min
# [Parallel(n_jobs
finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=6,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 20),
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'n_estimators': [90, 100, 115, 130]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
grid_search.best_score_
# Out:
# 0.8412685905643652

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 130}

# %%
rand_clf = RandomForestClassifier(criterion= 'gini',
 max_depth = 4,
 max_features = 'auto',
 min_samples_leaf = 1,
 min_samples_split= 5,
 n_estimators = 130,random_state=6)

# %%
rand_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=4, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=130,
#                        n_jobs=None, oob_score=False, random_state=6, verbose=0,
#                        warm_start=False)

# %%
rand_clf.score(x_test,y_test)
# Out:
# 0.7932960893854749

# %%
from sklearn.linear_model import LogisticRegression
# Create param grid.

param_grid ={'penalty' : ['l1', 'l2','elasticnet'],
    'C' : np.logspace(-5, 8, 15),
    'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']}
    

# Create grid search object

clf = GridSearchCV(LogisticRegression(), param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
best_clf = clf.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 225 candidates, totalling 675 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 675 out of 675 | elapsed:    1.9s finished

# %%
best_clf.score(x_test,y_test)
# Out:
# 0.9832402234636871

# %%
LG = LogisticRegression().fit(x_train, y_train)

# %%
LG.score(x_test,y_test)
# Out:
# 0.9832402234636871

# %%
final = LG.predict(x_new)

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch  Cabin  Embarked
# 0         3    1  22.0      1      0    145         2
# 1         1    0  38.0      1      0     81         0
# 2         3    0  26.0      0      0    145         2
# 3         1    0  35.0      1      0     55         2
# 4         3    1  35.0      0      0    145         2
# ..      ...  ...   ...    ...    ...    ...       ...
# 886       2    1  27.0      0      0    145         2
# 887       1    0  19.0      0      0     30         2
# 888       3    0  30.0      1      2    145         2
# 889       1    1  26.0      0      0     60         0
# 890       3    1  32.0      0      0    145         1
#
# [891 rows x 7 columns]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
models = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    DecisionTreeClassifier(max_depth=10),
    RandomForestClassifier(n_estimators=100),
    MLPClassifier(),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()
]

for model in models:
    model.fit(x_train, y_train)
    score = model.score(x_test, y_test)
    print(score,model)
# Out:
# 0.9776536312849162 KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')
# 0.9888268156424581 SVC(C=0.025, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# 0.9832402234636871 SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=2, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)
# 0.9553072625698324 DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=10, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# 0.9608938547486033 RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.9832402234636871 MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# 0.9608938547486033 AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)
# 0.888268156424581 GaussianNB(priors=None, var_smoothing=1e-09)
# 0.9608938547486033 QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
param_grid={'C':[0.1,1,10,50,100,500],'gamma':[1,0.5,0.1,0.01,0.001]}

# %%
grid= GridSearchCV(SVC(),param_grid, verbose=3, n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:    0.9s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 50, 100, 500],
#                          'gamma': [1, 0.5, 0.1, 0.01, 0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.5}

# %%
model_new=SVC(C=10, gamma=0.5)
model_new.fit(x_train,y_train)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.5, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model_new.score(x_test,y_test)
# Out:
# 0.9832402234636871

# %%
df1=pd.read_csv("test.csv")
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df1.drop(["Name","Ticket","Fare","PassengerId"],axis=1,inplace=True)
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0         3    male  34.5      0      0   NaN        Q
# 1         3  female  47.0      1      0   NaN        S
# 2         2    male  62.0      0      0   NaN        Q
# 3         3    male  27.0      0      0   NaN        S
# 4         3  female  22.0      1      1   NaN        S
# ..      ...     ...   ...    ...    ...   ...      ...
# 413       3    male   NaN      0      0   NaN        S
# 414       1  female  39.0      0      0  C105        C
# 415       3    male  38.5      0      0   NaN        S
# 416       3    male   NaN      0      0   NaN        S
# 417       3    male   NaN      1      1   NaN        C
#
# [418 rows x 7 columns]

# %%
df1["Sex"] = LabelEncoder().fit_transform(df1["Sex"])

# %%
df1.isnull().any()
# Out:
# Pclass      False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Cabin        True
# Embarked    False
# dtype: bool

# %%
df1["Age"].fillna(df1["Age"].mean(),inplace=True)

# %%
df1["Age"] = df1["Age"].astype(int)

# %%
df1["Embarked"] = LabelEncoder().fit_transform(df1["Embarked"])

# %%
df1["Cabin"].value_counts()
# Out:
# B57 B59 B63 B66    3
# C89                2
# C116               2
# C31                2
# C6                 2
#                   ..
# C106               1
# A29                1
# B26                1
# E31                1
# D22                1
# Name: Cabin, Length: 76, dtype: int64

# %%
len(np.where(df1["Cabin"].isnull())[0])
# Out:
# 327

# %%
df1["Cabin"].fillna("B57 B59 B63 B66",inplace=True)

# %%
df1.isnull().any()
# Out:
# Pclass      False
# Sex         False
# Age         False
# SibSp       False
# Parch       False
# Cabin       False
# Embarked    False
# dtype: bool

# %%
df1["Cabin"] = LabelEncoder().fit_transform(df1["Cabin"])

# %%
df1
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Cabin  Embarked
# 0         3    1   34      0      0     15         1
# 1         3    0   47      1      0     15         2
# 2         2    1   62      0      0     15         1
# 3         3    1   27      0      0     15         2
# 4         3    0   22      1      1     15         2
# ..      ...  ...  ...    ...    ...    ...       ...
# 413       3    1   30      0      0     15         2
# 414       1    0   39      0      0     22         0
# 415       3    1   38      0      0     15         2
# 416       3    1   30      0      0     15         2
# 417       3    1   30      1      1     15         0
#
# [418 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_datan=scaler.fit_transform(df1)
scaled_datan
# Out:
# array([[ 0.87348191,  0.75592895,  0.3013391 , ..., -0.4002477 ,
#         -0.35149045, -0.47091535],
#        [ 0.87348191, -1.32287566,  1.32990486, ..., -0.4002477 ,
#         -0.35149045,  0.70076689],
#        [-0.31581919,  0.75592895,  2.51671149, ..., -0.4002477 ,
#         -0.35149045, -0.47091535],
#        ...,
#        [ 0.87348191,  0.75592895,  0.61782087, ..., -0.4002477 ,
#         -0.35149045,  0.70076689],
#        [ 0.87348191,  0.75592895, -0.01514267, ..., -0.4002477 ,
#         -0.35149045,  0.70076689],
#        [ 0.87348191,  0.75592895, -0.01514267, ...,  0.61989583,
#         -0.35149045, -1.64259759]])

# %%
dfn=pd.DataFrame(data=scaled_datan, columns= df1.columns)
dfn
# Out:
#        Pclass       Sex       Age     SibSp     Parch     Cabin  Embarked
# 0    0.873482  0.755929  0.301339 -0.499470 -0.400248 -0.351490 -0.470915
# 1    0.873482 -1.322876  1.329905  0.616992 -0.400248 -0.351490  0.700767
# 2   -0.315819  0.755929  2.516711 -0.499470 -0.400248 -0.351490 -0.470915
# 3    0.873482  0.755929 -0.252504 -0.499470 -0.400248 -0.351490  0.700767
# 4    0.873482 -1.322876 -0.648106  0.616992  0.619896 -0.351490  0.700767
# ..        ...       ...       ...       ...       ...       ...       ...
# 413  0.873482  0.755929 -0.015143 -0.499470 -0.400248 -0.351490  0.700767
# 414 -1.505120 -1.322876  0.696941 -0.499470 -0.400248  0.170042 -1.642598
# 415  0.873482  0.755929  0.617821 -0.499470 -0.400248 -0.351490  0.700767
# 416  0.873482  0.755929 -0.015143 -0.499470 -0.400248 -0.351490  0.700767
# 417  0.873482  0.755929 -0.015143  0.616992  0.619896 -0.351490 -1.642598
#
# [418 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
pca = PCA()
principalComponentsn = pca.fit_transform(dfn)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %%
pca = PCA(n_components=5)
new_data = pca.fit_transform(dfn)
# This will be the new data fed to the algorithm.
principal_Dfn = pd.DataFrame(data = new_data
             , columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4','principal component 5'])

# %%
x_new = principal_Dfn
x_new
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                -0.392574              -1.028918               0.010651
# 1                -0.142433               0.487382               0.000815
# 2                 1.431634              -1.169448               1.192876
# 3                -1.129179              -0.934322               0.350313
# 4                -1.193879               1.332875              -0.656586
# ..                     ...                    ...                    ...
# 413              -1.011228              -0.957334               0.451577
# 414               2.226237              -0.008297              -1.290134
# 415              -0.696694              -1.018697               0.721614
# 416              -1.011228              -0.957334               0.451577
# 417              -0.237422               0.300683              -0.193105
#
#      principal component 4  principal component 5
# 0                 0.094483              -0.744078
# 1                -1.426973               0.406820
# 2                -1.097095              -0.919083
# 3                 0.095538               0.204932
# 4                -0.531152               0.521923
# ..                     ...                    ...
# 413              -0.020689               0.169573
# 414              -0.718494              -0.431058
# 415              -0.330625               0.075282
# 416              -0.020689               0.169573
# 417               0.706806              -1.983720
#
# [418 rows x 5 columns]

# %%
final = model_new.predict(x_new)

# %%
len(final)
# Out:
# 418

# %%
df_final = pd.DataFrame()

df_final["PassengerId"] = list(range(892,1310))
df_final["Survived"] = final
df_final
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         1
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df_final["Survived"].value_counts()
# Out:
# 0    260
# 1    158
# Name: Survived, dtype: int64

# %%
df_final.to_csv('test_survived.csv', index=False)

# %%
s = pd.read_csv("test_survived.csv")
s
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         1
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

df['Sex'] = LabelEncoder().fit_transform(df['Sex'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas    0  27.0      0
# 887                       Graham, Miss. Margaret Edith    0  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0   NaN      1
# 889                              Behr, Mr. Karl Howell    0  26.0      0
# 890                                Dooley, Mr. Patrick    0  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
param_grid = { "criterion" : ["gini", "entropy"], "min_samples_leaf" : [1, 5, 10, 25, 50, 70], "min_samples_split" : [2, 4, 10, 12, 16, 18, 25, 35], "n_estimators": [100, 400, 700, 1000, 1500]}
from sklearn.model_selection import GridSearchCV, cross_val_score
rf = RandomForestClassifier(n_estimators=100, max_features='auto', oob_score=True, random_state=1, n_jobs=-1)
clf = GridSearchCV(estimator=rf, param_grid=param_grid, n_jobs=-1)

# %%
clf.fit(x_train, y_train)
